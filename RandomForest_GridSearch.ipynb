# %%
import pandas as pd
import numpy as np
from rdkit import Chem
from rdkit.Chem import AllChem

train_data_linear_filled = pd.read_csv('train_linear.csv')
test_data_linear_filled = pd.read_csv('test_linear.csv')

# SMILES 문자열에서 fingerprint를 생성하는 함수
def generate_fingerprint(smiles_string):
    mol = Chem.MolFromSmiles(smiles_string)
    if mol is not None:
        fingerprint = AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=2048)
        return list(fingerprint)
    else:
        return [0]*2048

# 모든 SMILES 문자열에 대해 fingerprint를 생성
fingerprint_data = train_data_linear_filled['SMILES'].apply(generate_fingerprint)
fingerprint_df = pd.DataFrame(fingerprint_data.tolist(), columns=[f'bit_{i}' for i in range(2048)])

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor

rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)

# 데이터 분리
X_train = pd.concat([train_data_linear_filled.drop(columns=['id', 'SMILES', 'MLM', 'HLM']), fingerprint_df], axis=1)
y_train_MLM = train_data_linear_filled['MLM']
y_train_HLM = train_data_linear_filled['HLM']

# RandomForestRegressor에 대한 하이퍼파라미터 그리드 설정
param_grid = {
    'n_estimators': [10, 30, 50, 100, 150, 200],
    'max_depth': [None, 1, 3, 5, 7, 10, 15, 20, 25, 30],
    'min_samples_split': [2, 5, 10, 15, 20],
    'min_samples_leaf': [1, 2, 4, 6, 8],
    'bootstrap': [True, False]
}

# GridSearchCV 설정
grid_search_MLM = GridSearchCV(estimator=rf_regressor, param_grid=param_grid, 
                           cv=3, n_jobs=-1, verbose=2, scoring='neg_root_mean_squared_error')
grid_search_HLM = GridSearchCV(estimator=rf_regressor, param_grid=param_grid, 
                           cv=3, n_jobs=-1, verbose=2, scoring='neg_root_mean_squared_error')

# RandomizedSearchCV 설정
random_search_MLM = RandomizedSearchCV(estimator=rf_regressor, param_distributions=param_grid, 
                                   n_iter=100, cv=3, n_jobs=-1, verbose=2, random_state=42, scoring='neg_root_mean_squared_error')
random_search_HLM = RandomizedSearchCV(estimator=rf_regressor, param_distributions=param_grid, 
                                   n_iter=100, cv=3, n_jobs=-1, verbose=2, random_state=42, scoring='neg_root_mean_squared_error')

# GridSearchCV 실행
grid_search_MLM.fit(X_train, y_train_MLM)
grid_search_HLM.fit(X_train, y_train_HLM)


# RandomizedSearchCV 실행
random_search_MLM.fit(X_train, y_train_MLM)
random_search_HLM.fit(X_train, y_train_HLM)
# Out:
# Fitting 3 folds for each of 3000 candidates, totalling 9000 fits
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=30; total time=  13.6s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time= 1.1min
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=150; total time= 1.1min
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  40.6s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=15, n_estimators=10; total time=   4.4s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=15, n_estimators=10; total time=   4.3s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=15, n_estimators=30; total time=  12.2s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=  44.2s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=10; total time=   4.8s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=10; total time=   3.9s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=30; total time=  11.9s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=50; total time=  20.5s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=150; total time= 1.0min
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=  56.3s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  36.5s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=10; total time=   3.5s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=30; total time=  10.1s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  35.6s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time= 1.2min
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=20, n_estimators=50; total time=  17.2s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=20, n_estimators=150; total time=  48.5s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  22.5s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  45.8s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=  11.6s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  22.4s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=15, n_estimators=30; total time=   6.8s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=15, n_estimators=50; total time=  10.9s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=15, n_estimators=200; total time=  45.8s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=20, n_estimators=200; total time=  42.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=6, min_samples_split=5, n_estimators=30; total time=   5.1s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=6, min_samples_split=5, n_estimators=100; total time=  17.5s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=6, min_samples_split=10, n_estimators=10; total time=   1.9s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=6, min_samples_split=10, n_estimators=30; total time=   5.5s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=6, min_samples_split=10, n_estimators=50; total time=   8.7s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=6, min_samples_split=10, n_estimators=200; total time=  36.9s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=6, min_samples_split=15, n_estimators=200; total time=  33.6s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=8, min_samples_split=2, n_estimators=10; total time=   1.7s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=8, min_samples_split=2, n_estimators=30; total time=   4.4s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=8, min_samples_split=2, n_estimators=100; total time=  15.6s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=8, min_samples_split=2, n_estimators=200; total time=  29.2s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=8, min_samples_split=10, n_estimators=30; total time=   4.4s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=8, min_samples_split=10, n_estimators=50; total time=   7.4s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=8, min_samples_split=10, n_estimators=150; total time=  22.2s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=8, min_samples_split=15, n_estimators=150; total time=  22.1s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=8, min_samples_split=20, n_estimators=100; total time=  14.4s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=1, min_samples_split=2, n_estimators=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=1, min_samples_split=2, n_estimators=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=1, min_samples_split=2, n_estimators=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=1, min_samples_split=2, n_estimators=30; total time=   0.3s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=1, min_samples_split=2, n_estimators=30; total time=   0.3s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.6s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=   1.4s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.9s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=1, min_samples_split=5, n_estimators=150; total time=   1.4s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=1, min_samples_split=10, n_estimators=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=1, min_samples_split=10, n_estimators=30; total time=   0.3s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=1, min_samples_split=15, n_estimators=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=1, min_samples_split=15, n_estimators=10; total time=   0.2s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=1, min_samples_split=15, n_estimators=10; total time=   0.2s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=1, min_samples_split=15, n_estimators=30; total time=   0.3s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=1, min_samples_split=15, n_estimators=50; total time=   0.5s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=1, min_samples_split=15, n_estimators=150; total time=   1.4s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=1, min_samples_split=20, n_estimators=30; total time=   0.3s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=1, min_samples_split=20, n_estimators=50; total time=   0.5s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=1, min_samples_split=20, n_estimators=150; total time=   1.4s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=2, min_samples_split=2, n_estimators=30; total time=   0.3s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.5s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=2, min_samples_split=5, n_estimators=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=2, min_samples_split=5, n_estimators=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=2, min_samples_split=5, n_estimators=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=2, min_samples_split=5, n_estimators=30; total time=   0.3s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=2, min_samples_split=5, n_estimators=150; total time=   1.4s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=2, min_samples_split=10, n_estimators=30; total time=   0.3s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=2, min_samples_split=15, n_estimators=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=2, min_samples_split=15, n_estimators=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=2, min_samples_split=15, n_estimators=30; total time=   0.3s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=2, min_samples_split=15, n_estimators=30; total time=   0.3s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=2, min_samples_split=15, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=2, min_samples_split=20, n_estimators=10; total time=   0.2s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=2, min_samples_split=20, n_estimators=30; total time=   0.4s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=2, min_samples_split=20, n_estimators=50; total time=   0.5s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=2, min_samples_split=20, n_estimators=150; total time=   1.4s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=4, min_samples_split=2, n_estimators=150; total time=   1.3s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=4, min_samples_split=5, n_estimators=150; total time=   1.4s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=   1.4s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=4, min_samples_split=15, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=4, min_samples_split=20, n_estimators=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=4, min_samples_split=20, n_estimators=30; total time=   0.3s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=4, min_samples_split=20, n_estimators=50; total time=   0.5s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=4, min_samples_split=20, n_estimators=150; total time=   1.4s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=6, min_samples_split=2, n_estimators=150; total time=   1.4s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=6, min_samples_split=5, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=6, min_samples_split=10, n_estimators=10; total time=   0.2s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=6, min_samples_split=10, n_estimators=50; total time=   0.6s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=6, min_samples_split=10, n_estimators=150; total time=   1.5s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=6, min_samples_split=15, n_estimators=100; total time=   1.0s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=6, min_samples_split=20, n_estimators=10; total time=   0.1s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=6, min_samples_split=20, n_estimators=30; total time=   0.3s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=6, min_samples_split=20, n_estimators=50; total time=   0.5s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=6, min_samples_split=20, n_estimators=150; total time=   1.4s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=8, min_samples_split=2, n_estimators=150; total time=   1.4s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=8, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=8, min_samples_split=10, n_estimators=10; total time=   0.2s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=8, min_samples_split=10, n_estimators=30; total time=   0.3s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=8, min_samples_split=10, n_estimators=50; total time=   0.5s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=8, min_samples_split=10, n_estimators=200; total time=   1.9s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=8, min_samples_split=15, n_estimators=200; total time=   1.8s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=10; total time=   0.3s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=30; total time=   1.0s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=   4.6s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   3.1s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=10, n_estimators=30; total time=   1.0s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   1.6s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   6.3s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=   6.3s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=10; total time=   0.4s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=30; total time=   1.0s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   3.1s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   6.5s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   1.6s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=2, min_samples_split=10, n_estimators=150; total time=   4.7s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=2, min_samples_split=15, n_estimators=100; total time=   3.2s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=2, min_samples_split=20, n_estimators=10; total time=   0.4s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=2, min_samples_split=20, n_estimators=30; total time=   1.0s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=2, min_samples_split=20, n_estimators=50; total time=   1.6s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=2, min_samples_split=20, n_estimators=150; total time=   4.7s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=2, n_estimators=150; total time=   4.8s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   3.1s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=10; total time=   0.3s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=4, min_samples_split=10, n_estimators=30; total time=   1.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=10; total time=   5.0s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  47.8s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=  21.5s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  45.4s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=30; total time=  11.8s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=  20.3s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=150; total time= 1.0min
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=15, n_estimators=150; total time= 1.1min
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=  39.5s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=10; total time=   3.9s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=10; total time=   3.8s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=30; total time=  10.8s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  38.1s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time= 1.2min
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=30; total time=   9.7s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=  16.5s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=150; total time=  52.8s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=15, n_estimators=150; total time=  52.6s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=20, n_estimators=100; total time=  32.4s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=10; total time=   2.5s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=30; total time=   7.2s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=  11.3s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=150; total time=  36.1s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  22.4s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  45.8s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=15, n_estimators=50; total time=  11.2s
# [CV] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=15, n_estimators
#   File "/Users/syshin/miniforge3/envs/tensorflow/lib/python3.9/site-packages/sklearn/model_selection/_search.py", line 845, in evaluate_candidates
#     raise ValueError(
#   File "/Users/syshin/miniforge3/envs/tensorflow/lib/python3.9/site-packages/sklearn/utils/parallel.py", line 65, in __call__
#   File "/Users/syshin/miniforge3/envs/tensorflow/lib/python3.9/site-packages/joblib/parallel.py", line 1952, in __call__
#     return output if self.return_generator else list(output)
#   File "/Users/syshin/miniforge3/envs/tensorflow/lib/python3.9/site-packages/joblib/parallel.py", line 1595, in _get_outputs
#     yield from self._retrieve()
#   File "/Users/syshin/miniforge3/envs/tensorflow/lib/python3.9/site-packages/joblib/parallel.py", line 1707, in _retrieve
#     time.sleep(0.01)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/syshin/miniforge3/envs/tensorflow/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2105, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/Users/syshin/miniforge3/envs/tensorflow/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1428, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/Users/syshin/miniforge3/envs/tensorflow/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1319, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/Users/syshin/miniforge3/envs/tensorflow/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1172, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/Users/syshin/miniforge3/envs/tensorflow/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1087, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#   File "/Users/syshin/miniforge3/envs/tensorflow/lib/python3.9/site-packages/IPython/core/ultratb.py", line 969, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#   File "/Users/syshin/miniforge3/envs/tensorflow/lib/python3.9/site-packages/IPython/core/ultratb.py", line 792, in lines
#     return self._sd.lines
#   File "/Users/syshin/miniforge3/envs/tensorflow/lib/python3.9/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/Users/syshin/miniforge3/envs/tensorflow/lib/python3.9/site-packages/stack_data/core.py", line 734, in lines
#     pieces = self.included_pieces
#   File "/Users/syshin/miniforge3/envs/tensorflow/lib/python3.9/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/Users/syshin/miniforge3/envs/tensorflow/lib/python3.9/site-packages/stack_data/core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/Users/syshin/miniforge3/envs/tensorflow/lib/python3.9/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/Users/syshin/miniforge3/envs/tensorflow/lib/python3.9/site-packages/stack_data/core.py", line 660, in executing_piece
#     return only(
#   File "/Users/syshin/miniforge3/envs/tensorflow/lib/python3.9/site-packages/executing/executing.py", line 190, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
print('===MLM===')
print(grid_search_MLM.best_params_, grid_search_MLM.best_score_)
print(random_search_MLM.best_params_, random_search_MLM.best_score_)
print()
print('===HLM===')
print(grid_search_HLM.best_params_, grid_search_HLM.best_score_)
print(random_search_HLM.best_params_, random_search_HLM.best_score_)

# %%
# 가장 좋은 파라미터 저장
best_params_MLM = {}
best_params_HLM = {}

if grid_search_MLM.best_score_ > random_search_MLM.best_score_:
    best_params_MLM = grid_search_MLM.best_params_
else:
    best_params_MLM = random_search_MLM.best_params_

if grid_search_HLM.best_score_ > random_search_HLM.best_score_:
    best_params_HLM = grid_search_HLM.best_params_
else:
    best_params_HLM = random_search_HLM.best_params_

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor


# 2. 최적의 하이퍼파라미터를 사용하여 RandomForestRegressor 학습
# rf_params_MLM = {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 150}
# rf_params_HLM = {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100}
rf_regressor_MLM = RandomForestRegressor(**best_params_MLM)
rf_regressor_HLM = RandomForestRegressor(**best_params_HLM)
rf_regressor_MLM.fit(X_train, y_train_MLM)
rf_regressor_HLM.fit(X_train, y_train_HLM)

# 3. test_linear.csv 데이터 로드
test_data = pd.read_csv('test_linear.csv')

# fingerprint 생성
fingerprint_data_test = test_data['SMILES'].apply(generate_fingerprint)
fingerprint_df_test = pd.DataFrame(fingerprint_data_test.tolist(), columns=[f'bit_{i}' for i in range(2048)])

# 테스트 데이터의 특성 준비
id_col = test_data['id']
X_test = pd.concat([test_data.drop(columns=['id', 'SMILES']), fingerprint_df_test], axis=1)

# 4. 학습된 모델로 test_linear.csv 데이터의 결과 예측
predictions_MLM = rf_regressor_MLM.predict(X_test)
predictions_HLM = rf_regressor_HLM.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

# 실제 MLM, HLM 값 가져오기
y_test_MLM = test_data['MLM']
y_test_HLM = test_data['HLM']

# MLM, HLM에 대한 RMSE 계산
rmse_MLM = mean_squared_error(y_test_MLM, predictions_MLM, squared=False)
rmse_HLM = mean_squared_error(y_test_HLM, predictions_HLM, squared=False)

print(rmse_MLM) 
print(rmse_HLM)

# %%
id_col = test_data['id']

# 예측 값을 DataFrame으로 변환
predictions_df = pd.DataFrame({
    'id': id_col,
    'MLM': predictions_MLM,
    'HLM': predictions_HLM
})

predictions_df

# %%
predictions_df.to_csv('rf_grid_search_submission.csv', index=False)
