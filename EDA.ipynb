# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('train.csv')
df
# Out:
#               id                                             SMILES     MLM  \
# 0     TRAIN_0000    CCOc1ccc(CNC(=O)c2cc(-c3sc(C)nc3C)n[nH]2)cc1OCC  26.010
# 1     TRAIN_0001               Cc1nc(C)c(CN2CC(C)C(=O)Nc3ccccc32)s1  29.270
# 2     TRAIN_0002                   CCCN1CCN(c2nn3nnnc3c3ccccc23)CC1   5.586
# 3     TRAIN_0003  Cc1ccc(-c2ccc(-n3nc(C)c(S(=O)(=O)N4CCN(C5CCCCC...   5.710
# 4     TRAIN_0004                Cc1ccc2c(c1)N(C(=O)c1ccncc1)CC(C)O2  93.270
# ...          ...                                                ...     ...
# 3493  TRAIN_3493     Cn1nc(CNC(=O)Cn2nc(C(F)(F)F)c3c2CCC3)c(Cl)c1Cl   1.556
# 3494  TRAIN_3494  CCn1[nH]cc/c1=N\C(=O)c1nn(-c2ccccc2)c(=O)c2ccc...  35.560
# 3495  TRAIN_3495                       CCOC(=O)CCCc1nc2cc(N)ccc2n1C  56.150
# 3496  TRAIN_3496                     Nc1cc(C(=O)OCCC2CCOC2=O)cnc1Cl   0.030
# 3497  TRAIN_3497                   COc1ccc(-c2nc(Cc3ccccc3)sc2C)cc1   0.450
#
#          HLM  AlogP  Molecular_Weight  Num_H_Acceptors  Num_H_Donors  \
# 0     50.680  3.259           400.495                5             2
# 1     50.590  2.169           301.407                2             1
# 2     80.892  1.593           297.358                5             0
# 3      2.000  4.771           494.652                6             0
# 4     99.990  2.335           268.310                3             0
# ...      ...    ...               ...              ...           ...
# 3493   3.079  3.409           396.195                3             1
# 3494  47.630  1.912           359.381                4             1
# 3495   1.790  1.941           261.320                3             1
# 3496   2.770  0.989           284.696                5             1
# 3497   2.650  4.321           295.399                2             0
#
#       Num_RotatableBonds   LogD  Molecular_PolarSurfaceArea
# 0                      8  3.259                      117.37
# 1                      2  2.172                       73.47
# 2                      3  1.585                       62.45
# 3                      5  3.475                       92.60
# 4                      1  2.337                       42.43
# ...                  ...    ...                         ...
# 3493                   5  3.409                       64.74
# 3494                   3  1.844                       77.37
# 3495                   6  2.124                       70.14
# 3496                   5  0.989                       91.51
# 3497                   4  4.321                       50.36
#
# [3498 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3498 entries, 0 to 3497
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          3498 non-null   object
#  1   SMILES                      3498 non-null   object
#  2   MLM                         3498 non-null   float64
#  3   HLM                         3498 non-null   float64
#  4   AlogP                       3496 non-null   float64
#  5   Molecular_Weight            3498 non-null   float64
#  6   Num_H_Acceptors             3498 non-null   int64
#  7   Num_H_Donors                3498 non-null   int64
#  8   Num_RotatableBonds          3498 non-null   int64
#  9   LogD                        3498 non-null   float64
#  10  Molecular_PolarSurfaceArea  3498 non-null   float64
# dtypes: float64(6), int64(3), object(2)
# memory usage: 300.7+ KB

# %%
df.describe()
# Out:
#                MLM          HLM        AlogP  Molecular_Weight  \
# count  3498.000000  3498.000000  3496.000000       3498.000000
# mean     37.384742    53.090206     2.841399        363.881846
# std      35.695993    36.080081     1.608073         79.527022
# min       0.000000     0.000000    -4.137000        172.180000
# 25%       2.433000    15.905500     1.833000        304.389750
# 50%      26.193000    58.023000     2.889000        350.255000
# 75%      70.807250    87.753000     3.958250        409.744750
# max     131.720000   135.336000     9.190000       1360.467000
#
#        Num_H_Acceptors  Num_H_Donors  Num_RotatableBonds         LogD  \
# count      3498.000000   3498.000000         3498.000000  3498.000000
# mean          4.016581      1.098628            4.561178     2.682156
# std           1.511091      0.976266            2.357243     1.666996
# min           0.000000      0.000000            0.000000    -4.920000
# 25%           3.000000      0.000000            3.000000     1.620000
# 50%           4.000000      1.000000            4.000000     2.709000
# 75%           5.000000      2.000000            6.000000     3.860000
# max          15.000000     10.000000           38.000000     9.190000
#
#        Molecular_PolarSurfaceArea
# count                 3498.000000
# mean                    79.747278
# std                     28.849229
# min                      3.240000
# 25%                     60.150000
# 50%                     77.525000
# 75%                     96.540000
# max                    296.430000

# %%
df.isnull().sum()
# Out:
# id                            0
# SMILES                        0
# MLM                           0
# HLM                           0
# AlogP                         2
# Molecular_Weight              0
# Num_H_Acceptors               0
# Num_H_Donors                  0
# Num_RotatableBonds            0
# LogD                          0
# Molecular_PolarSurfaceArea    0
# dtype: int64

# %%
df.MLM.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.HLM.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.corr()
# Out:
#                                  MLM       HLM     AlogP  Molecular_Weight  \
# MLM                         1.000000  0.706725 -0.330083         -0.081239
# HLM                         0.706725  1.000000 -0.346022         -0.175117
# AlogP                      -0.330083 -0.346022  1.000000          0.389760
# Molecular_Weight           -0.081239 -0.175117  0.389760          1.000000
# Num_H_Acceptors             0.164510  0.092313 -0.284415          0.471814
# Num_H_Donors                0.210836  0.176549 -0.172222          0.116186
# Num_RotatableBonds         -0.092563 -0.132263  0.111844          0.583711
# LogD                       -0.350146 -0.357456  0.957611          0.369462
# Molecular_PolarSurfaceArea  0.184850  0.094323 -0.298194          0.439114
#
#                             Num_H_Acceptors  Num_H_Donors  Num_RotatableBonds  \
# MLM                                0.164510      0.210836           -0.092563
# HLM                                0.092313      0.176549           -0.132263
# AlogP                             -0.284415     -0.172222            0.111844
# Molecular_Weight                   0.471814      0.116186            0.583711
# Num_H_Acceptors                    1.000000      0.208433            0.474012
# Num_H_Donors                       0.208433      1.000000            0.176871
# Num_RotatableBonds                 0.474012      0.176871            1.000000
# LogD                              -0.305506     -0.212082            0.071659
# Molecular_PolarSurfaceArea         0.714315      0.474614            0.371574
#
#                                 LogD  Molecular_PolarSurfaceArea
# MLM                        -0.350146                    0.184850
# HLM                        -0.357456                    0.094323
# AlogP                       0.957611                   -0.298194
# Molecular_Weight            0.369462                    0.439114
# Num_H_Acceptors            -0.305506                    0.714315
# Num_H_Donors               -0.212082                    0.474614
# Num_RotatableBonds          0.071659                    0.371574
# LogD                        1.000000                   -0.294670
# Molecular_PolarSurfaceArea -0.294670                    1.000000

# %%
import seaborn as sns

sns.pairplot(df.corr(), hue='MLM')

# %%
import matplotlib.pyplot as plt
import warnings

plt.rcParams['font.family'] = 'AppleGothic'
warnings.filterwarnings("ignore")
# %matplotlib inline

plt.figure(figsize=(15,15))
sns.heatmap(data=df.corr(), annot=True, fmt='.2f', linewidths=.5, cmap='RdYlBu_r')
# Out:
# <Axes: >

# %%
sns.clustermap(df.corr(),
               annot=True,
               cmap='RdYlBu_r'
              );
