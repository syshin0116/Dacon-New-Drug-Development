# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./submissions/train_linear.csv')
df
# Out:
#               id                                             SMILES     MLM  \
# 0     TRAIN_0000    CCOc1ccc(CNC(=O)c2cc(-c3sc(C)nc3C)n[nH]2)cc1OCC  26.010
# 1     TRAIN_0001               Cc1nc(C)c(CN2CC(C)C(=O)Nc3ccccc32)s1  29.270
# 2     TRAIN_0002                   CCCN1CCN(c2nn3nnnc3c3ccccc23)CC1   5.586
# 3     TRAIN_0003  Cc1ccc(-c2ccc(-n3nc(C)c(S(=O)(=O)N4CCN(C5CCCCC...   5.710
# 4     TRAIN_0004                Cc1ccc2c(c1)N(C(=O)c1ccncc1)CC(C)O2  93.270
# ...          ...                                                ...     ...
# 3493  TRAIN_3493     Cn1nc(CNC(=O)Cn2nc(C(F)(F)F)c3c2CCC3)c(Cl)c1Cl   1.556
# 3494  TRAIN_3494  CCn1[nH]cc/c1=N\C(=O)c1nn(-c2ccccc2)c(=O)c2ccc...  35.560
# 3495  TRAIN_3495                       CCOC(=O)CCCc1nc2cc(N)ccc2n1C  56.150
# 3496  TRAIN_3496                     Nc1cc(C(=O)OCCC2CCOC2=O)cnc1Cl   0.030
# 3497  TRAIN_3497                   COc1ccc(-c2nc(Cc3ccccc3)sc2C)cc1   0.450
#
# ...

# %%
X_MLM = df.drop(columns=['MLM', 'id', 'SMILES'])
X_HLM = df.drop(columns=['HLM', 'id', 'SMILES'])
Y_MLM = df['MLM']
Y_MLM = df['HLM']

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_regression
from sklearn.ensemble import RandomForestClassifier

# %%
bestfeatures = SelectKBest(score_func=mutual_info_regression, k=8)
fit = bestfeatures.fit(X_MLM, Y_MLM)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X_MLM.columns) 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Features','Score']  
print(featureScores.nlargest(8,'Score'))
# Out:
#                      Features     Score
# 0                         HLM  6.352275
# 6                        LogD  0.093341
# 1                       AlogP  0.080161
# 7  Molecular_PolarSurfaceArea  0.033406
# 4                Num_H_Donors  0.029693
# 2            Molecular_Weight  0.024969
# 3             Num_H_Acceptors  0.014743
# 5          Num_RotatableBonds  0.000000

# %%
model = RandomForestClassifier()
model.fit(X_MLM, Y_MLM)
print(model.feature_importances_)
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(8).plot(kind='barh')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/3m/knb96f9s4xg2t2gcrl96r6jh0000gn/T/ipykernel_5813/2936852879.py in <cell line: 2>()
#       1 model = RandomForestClassifier()
# ----> 2 model.fit(X_MLM, Y_MLM)
#       3 print(model.feature_importances_)
#       4 feat_importances = pd.Series(model.feature_importances_, index=X.columns)
#       5 feat_importances.nlargest(8).plot(kind='barh')
#
# ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     383         self.n_outputs_ = y.shape[1]
#     384
# --> 385         y, expanded_class_weight = self._validate_y_class_weight(y)
#     386
#     387         if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
#
# ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/sklearn/ensemble/_forest.py in _validate_y_class_weight(self, y)
# ...
