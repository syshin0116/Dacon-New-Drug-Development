# %%
pip install pycaret
# Out:
# ...
#   Obtaining dependency information for pycaret from https://files.pythonhosted.org/packages/f5/4b/2002980b046ac396618dfc152d384b812a78182b776ca77fe0ae5f80deac/pycaret-3.0.4-py3-none-any.whl.metadata
# ...
#   Using cached pandas-1.5.3-cp39-cp39-macosx_11_0_arm64.whl (11.0 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 33.2 MB/s eta 0:00:0031m33.5 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 15.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Obtaining dependency information for imbalanced-learn>=0.8.1 from https://files.pythonhosted.org/packages/a3/9e/fbe60a768502af54563dcb59ca7856f5a8833b3ad5ada658922e1ab09b7f/imbalanced_learn-0.11.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for category-encoders>=2.4.0 from https://files.pythonhosted.org/packages/1f/e2/495811f12b2e90753fff0e42a07adb0370a725de17cc23a579ac9d3ca67c/category_encoders-2.6.2-py2.py3-none-any.whl.metadata
# ...

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('train.csv')

# %%
from pycaret.regression import *
reg_test_MLM = setup(data=data,
                   target='MLM',
                   train_size= 0.8,
                   fold=5)
# Out:
# <style type="text/css">
# #T_30e58_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_30e58">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30e58_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_30e58_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30e58_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_30e58_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_30e58_row0_col1" class="data row0 col1" >3971</td>
#     </tr>
#     <tr>
#       <th id="T_30e58_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_30e58_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_30e58_row1_col1" class="data row1 col1" >MLM</td>
#     </tr>
#     <tr>
#       <th id="T_30e58_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
reg_test_HLM = setup(data=data,
                   target='HLM',
                   train_size= 0.8,
                   fold=5)
# Out:
# <style type="text/css">
# #T_d2aa5_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d2aa5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d2aa5_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d2aa5_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2aa5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d2aa5_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d2aa5_row0_col1" class="data row0 col1" >7692</td>
#     </tr>
#     <tr>
#       <th id="T_d2aa5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d2aa5_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d2aa5_row1_col1" class="data row1 col1" >HLM</td>
#     </tr>
#     <tr>
#       <th id="T_d2aa5_level0_row2" class="row_heading level0 row2" >2</th>
# ...
